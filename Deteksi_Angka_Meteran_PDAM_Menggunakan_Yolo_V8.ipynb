# %% [markdown]
# <a href="https://colab.research.google.com/github/Fadhilsaadat/Gender-Classification/blob/main/Deteksi_Angka_Meteran_PDAM_Menggunakan_Yolo_V8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 7.3 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/107.7 GB disk)

# %%
# !yolo detect train data=/content/drive/MyDrive/Yolo8/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train3/weights/best.pt source='/content/drive/MyDrive/Yolo8/Image/val/2A310001200175M.jpg' save=true
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3007793 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Yolo8/Image/val/2A310001200175M.jpg: 640x640 1 meteran, 1 3, 1 5, 1 7, 270.0ms
# Speed: 8.8ms preprocess, 270.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo val model=yolov8n.pt data=/content/drive/MyDrive/Colab\ Notebooks/Yolo8/data.yaml
# Out:
# Ultralytics YOLOv8.0.187 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/Colab Notebooks/Yolo8/Image/val.cache... 10 images, 0 backgrounds, 0 corrupt: 100% 10/10 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:03<00:00,  3.23s/it]
#                    all         10         70          0          0          0          0
# Speed: 15.5ms preprocess, 283.8ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo detect model=yolov8n.pt source='/content/drive/MyDrive/Colab Notebooks/Yolo8/Image/val/2A310001200158M.jpg'
# Out:
# WARNING ⚠️ 'mode' is missing. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark'). Using default 'mode=train'.
# WARNING ⚠️ 'data' is missing. Using default 'data=coco8.yaml'.
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
